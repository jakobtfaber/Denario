# %% [markdown]
# # Denario research idea example
#
# Through this notebook we show different ways to generate a research idea.

# %% [markdown]
# ## Import and instantiate the Denario class
#
# Initialize a `Denario` instance. All research assistance is performed through this object.

# %%
from denario import Denario

den = Denario()

# %% [markdown]
# ## Set the data and tools description
#
# Describe the topic of the research. Specify the data and tools to be employed.

# %%
data_description = r"""
Assume we have data on quantum phase of matter. 
We want to explore ideas on quantum states and tensor networks for numerical analysis.
Can tensor networks simulate proposal for quantum algorithms?
"""

den.set_data_description(data_description = data_description)
den.show_data_description()
# Out:
# Assume we have data on quantum phase of matter.
# We want to explore ideas on quantum states and tensor networks for numerical analysis.
# Can tensor networks simulate proposal for quantum algorithms?

# %% [markdown]
# ## Get Idea - default
#
# Generate a research idea from that data specification, using the cmbagent backend.

# %%
den.get_idea()
den.show_idea()
# Out:
# Assume we have data on quantum phase of matter.
# We want to explore ideas on quantum states and tensor networks for numerical analysis.
# Can tensor networks simulate proposal for quantum algorithms?
#
#
# --------------------------------------------------------------------------------
# Setting agents for the session...
#
#              Model       agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 plan_setter 0.00096            426                 13           439
#
# --------------------------------------------------------------------------------
# Plan constraints have been logged.
#
# --------------------------------------------------------------------------------
#
# Calling planner...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 planner 0.00498            650                460          1110
# **Plan:**
#    - Step 1:
#          * sub-task: Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
#          * agent: idea_maker
#          * bullet points:
#             - Brainstorm 5 distinct research project ideas.
#             - Ensure each idea leverages the provided data and explores the intersection of quantum states, tensor networks, and quantum algorithm simulation.
#             - Briefly describe each idea.
#
#    - Step 2:
#          * sub-task: Critique the 5 research project ideas.
#          * agent: idea_hater
#          * bullet points:
#             - Analyze the strengths and weaknesses of each idea.
#             - Identify any impractical, redundant, or unoriginal ideas.
#             - Suggest improvements or highlight potential pitfalls.
#
#    - Step 3:
#          * sub-task: Select and improve 2 out of the 5 research project ideas based on critiques.
#          * agent: idea_maker
#          * bullet points:
#             - Choose the 2 most promising ideas, considering the critiques.
#             - Refine and improve these ideas to address the weaknesses identified.
#             - Provide improved descriptions for the selected ideas.
#
#    - Step 4:
#          * sub-task: Critique the 2 improved research project ideas.
#          * agent: idea_hater
#          * bullet points:
#             - Evaluate the improvements made.
#             - Point out any remaining issues or suggest final refinements.
#             - Recommend which idea is stronger, if possible.
#
#    - Step 5:
#          * sub-task: Select the best idea out of the 2 improved ideas.
#          * agent: idea_maker
#          * bullet points:
#             - Choose the single best research project idea.
#             - Justify the selection based on previous critiques and improvements.
#
#    - Step 6:
#          * sub-task: Report the best idea as a scientific paper title with a 5-sentence description.
#          * agent: idea_maker
#          * bullet points:
#             - Create a compelling and descriptive scientific paper title.
#             - Write a concise 5-sentence summary of the research project idea, highlighting its novelty, objectives, and potential impact.
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 planner_response_formatter 0.00449            719                382          1101
#
# **PLAN**
#
# - Step 1:
# 	* sub-task: Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Brainstorm 5 distinct research project ideas.
# 		- Ensure each idea leverages the provided data and explores the intersection of quantum states, tensor networks, and quantum algorithm simulation.
# 		- Briefly describe each idea.
#
# - Step 2:
# 	* sub-task: Critique the 5 research project ideas.
# 	* agent in charge: idea_hater
#
# 	* instructions:
# 		- Analyze the strengths and weaknesses of each idea.
# 		- Identify any impractical, redundant, or unoriginal ideas.
# 		- Suggest improvements or highlight potential pitfalls.
#
# - Step 3:
# 	* sub-task: Select and improve 2 out of the 5 research project ideas based on critiques.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Choose the 2 most promising ideas, considering the critiques.
# 		- Refine and improve these ideas to address the weaknesses identified.
# 		- Provide improved descriptions for the selected ideas.
#
# - Step 4:
# 	* sub-task: Critique the 2 improved research project ideas.
# 	* agent in charge: idea_hater
#
# 	* instructions:
# 		- Evaluate the improvements made.
# 		- Point out any remaining issues or suggest final refinements.
# 		- Recommend which idea is stronger, if possible.
#
# - Step 5:
# 	* sub-task: Select the best idea out of the 2 improved ideas.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Choose the single best research project idea.
# 		- Justify the selection based on previous critiques and improvements.
#
# - Step 6:
# 	* sub-task: Report the best idea as a scientific paper title with a 5-sentence description.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Create a compelling and descriptive scientific paper title.
# 		- Write a concise 5-sentence summary of the research project idea, highlighting its novelty, objectives, and potential impact.
#
#
#
# --------------------------------------------------------------------------------
# Recording plan...
#
#              Model         agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 plan_recorder 0.00581            783                531          1314
#
# --------------------------------------------------------------------------------
# Plan has been logged.
#
# --------------------------------------------------------------------------------
# Reviewing plan...
#
#              Model         agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# o3-mini-2025-01-31 plan_reviewer 0.00669           2803                819          3622
# Recommendations:
#
# - In Step 1, instruct idea_maker to not only brainstorm and briefly describe each idea but also to clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms. This ensures a more focused generation of ideas.
#
# - In Step 2, ask idea_hater to emphasize constructive critique by identifying specific impractical elements or gaps in each idea, and explicitly recommend targeted improvements. Clearer instructions for identifying both strengths and weaknesses will provide better feedback.
#
# - In Step 3, modify the instructions for idea_maker to include a requirement for integrating the critique into actionable improvements. For example, they should indicate explicitly how the refined ideas overcome the shortcomings highlighted by idea_hater.
#
# - In Step 4, prompt idea_hater to provide a final summary remark on the viability and innovativeness of each improved idea, ensuring that the comparison leads to a clearer recommendation on which idea is stronger.
#
# - In Step 5, request that idea_maker justify the final selection by linking back to specific feedback from idea_hater, ensuring that the final choice is clearly grounded in the prior critiques and improvements.
#
# - In Step 6, enhance the instructions for idea_maker by emphasizing that the 5-sentence scientific paper description should include: a clear statement of novelty, the research objectives, the methodological approach, anticipated impact, and a brief contextual motivation, thereby ensuring the final deliverable is comprehensive and compelling.
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                       agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 reviewer_response_formatter 0.00312            394                292           686
#
# **Recommendations:**
#
# In Step 1, instruct idea_maker to not only brainstorm and briefly describe each idea but also to clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms. This ensures a more focused generation of ideas.
#
# In Step 2, ask idea_hater to emphasize constructive critique by identifying specific impractical elements or gaps in each idea, and explicitly recommend targeted improvements. Clearer instructions for identifying both strengths and weaknesses will provide better feedback.
#
# In Step 3, modify the instructions for idea_maker to include a requirement for integrating the critique into actionable improvements. For example, they should indicate explicitly how the refined ideas overcome the shortcomings highlighted by idea_hater.
#
# In Step 4, prompt idea_hater to provide a final summary remark on the viability and innovativeness of each improved idea, ensuring that the comparison leads to a clearer recommendation on which idea is stronger.
#
# In Step 5, request that idea_maker justify the final selection by linking back to specific feedback from idea_hater, ensuring that the final choice is clearly grounded in the prior critiques and improvements.
#
# In Step 6, enhance the instructions for idea_maker by emphasizing that the 5-sentence scientific paper description should include: a clear statement of novelty, the research objectives, the methodological approach, anticipated impact, and a brief contextual motivation, thereby ensuring the final deliverable is comprehensive and compelling.
#
#
#
#
# --------------------------------------------------------------------------------
# Recording recommendations...
#
#              Model           agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 review_recorder 0.00319            376                305           681
#
# --------------------------------------------------------------------------------
#
# Recommendations have been logged.
# Number of feedback rounds left: 0.
# Now, update the plan accordingly, planner!
#
# --------------------------------------------------------------------------------
#
# Calling planner...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 planner 0.01616           4067               1003          5070
# **Updated Plan:**
#
# - Step 1:
# 	* sub-task: Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
# 	* agent in charge: idea_maker
# 	* instructions:
# 		- Brainstorm 5 distinct research project ideas.
# 		- For each idea, briefly describe the concept.
# 		- Clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms.
#
# - Step 2:
# 	* sub-task: Critique the 5 research project ideas.
# 	* agent in charge: idea_hater
# 	* instructions:
# 		- Analyze the strengths and weaknesses of each idea.
# 		- Identify specific impractical elements or gaps in each idea.
# 		- Explicitly recommend targeted improvements for each idea.
#
# - Step 3:
# 	* sub-task: Select and improve 2 out of the 5 research project ideas based on critiques.
# 	* agent in charge: idea_maker
# 	* instructions:
# 		- Choose the 2 most promising ideas, considering the critiques.
# 		- Refine and improve these ideas, explicitly indicating how the refinements overcome the shortcomings highlighted by idea_hater.
# 		- Provide improved descriptions for the selected ideas.
#
# - Step 4:
# 	* sub-task: Critique the 2 improved research project ideas.
# 	* agent in charge: idea_hater
# 	* instructions:
# 		- Evaluate the improvements made to each idea.
# 		- Point out any remaining issues or suggest final refinements.
# 		- Provide a final summary remark on the viability and innovativeness of each improved idea, and recommend which idea is stronger.
#
# - Step 5:
# 	* sub-task: Select the best idea out of the 2 improved ideas.
# 	* agent in charge: idea_maker
# 	* instructions:
# 		- Choose the single best research project idea.
# 		- Justify the selection by linking back to specific feedback from idea_hater, ensuring the final choice is clearly grounded in the prior critiques and improvements.
#
# - Step 6:
# 	* sub-task: Report the best idea as a scientific paper title with a 5-sentence description.
# 	* agent in charge: idea_maker
# 	* instructions:
# 		- Create a compelling and descriptive scientific paper title.
# 		- Write a concise 5-sentence summary of the research project idea, including: a clear statement of novelty, the research objectives, the methodological approach, anticipated impact, and a brief contextual motivation.
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 planner_response_formatter 0.00968           1521                830          2351
#
# **PLAN**
#
# - Step 1:
# 	* sub-task: Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Brainstorm 5 distinct research project ideas.
# 		- For each idea, briefly describe the concept.
# 		- Clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms.
#
# - Step 2:
# 	* sub-task: Critique the 5 research project ideas.
# 	* agent in charge: idea_hater
#
# 	* instructions:
# 		- Analyze the strengths and weaknesses of each idea.
# 		- Identify specific impractical elements or gaps in each idea.
# 		- Explicitly recommend targeted improvements for each idea.
#
# - Step 3:
# 	* sub-task: Select and improve 2 out of the 5 research project ideas based on critiques.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Choose the 2 most promising ideas, considering the critiques.
# 		- Refine and improve these ideas, explicitly indicating how the refinements overcome the shortcomings highlighted by idea_hater.
# 		- Provide improved descriptions for the selected ideas.
#
# - Step 4:
# 	* sub-task: Critique the 2 improved research project ideas.
# 	* agent in charge: idea_hater
#
# 	* instructions:
# 		- Evaluate the improvements made to each idea.
# 		- Point out any remaining issues or suggest final refinements.
# 		- Provide a final summary remark on the viability and innovativeness of each improved idea, and recommend which idea is stronger.
#
# - Step 5:
# 	* sub-task: Select the best idea out of the 2 improved ideas.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Choose the single best research project idea.
# 		- Justify the selection by linking back to specific feedback from idea_hater, ensuring the final choice is clearly grounded in the prior critiques and improvements.
#
# - Step 6:
# 	* sub-task: Report the best idea as a scientific paper title with a 5-sentence description.
# 	* agent in charge: idea_maker
#
# 	* instructions:
# 		- Create a compelling and descriptive scientific paper title.
# 		- Write a concise 5-sentence summary of the research project idea, including: a clear statement of novelty, the research objectives, the methodological approach, anticipated impact, and a brief contextual motivation.
#
#
#
# --------------------------------------------------------------------------------
# Recording plan...
#
#              Model         agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 plan_recorder 0.01234           1632               1134          2766
#
# --------------------------------------------------------------------------------
# Planning stage complete. Exiting.
#
# --------------------------------------------------------------------------------
# Terminating...
#
#              Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 terminator 0.00873           4361                  1          4362
#
# --------------------------------------------------------------------------------
# Session terminated.
#
# --------------------------------------------------------------------------------
#
# Displaying cost…
#
# | Agent                       | Cost ($)    | Prompt Tokens | Completion Tokens | Total Tokens |
# |:----------------------------|------------:|--------------:|------------------:|-------------:|
# | terminator                  | $0.00873000 |          4361 |                 1 |         4362 |
# | plan setter                 | $0.00095600 |           426 |                13 |          439 |
# | review recorder             | $0.00319200 |           376 |               305 |          681 |
# | plan reviewer               | $0.00668690 |          2803 |               819 |         3622 |
# | reviewer response formatter | $0.00312400 |           394 |               292 |          686 |
# | planner response formatter  | $0.01417600 |          2240 |              1212 |         3452 |
# | planner                     | $0.02113800 |          4717 |              1463 |         6180 |
# | plan recorder               | $0.01815000 |          2415 |              1665 |         4080 |
# |-----------------------------|-------------|---------------|-------------------|--------------|
# | Total                       | $0.07615290 |         17732 |              5770 |        23502 |
#
# Cost report data saved to: /home/tda/PABLO/AstroPilot/examples/project/idea_generation_output/planning/cost_report_20250724_160113.json
#
# Structured plan written to /home/tda/PABLO/AstroPilot/examples/project/idea_generation_output/planning/final_plan.json
# Planning took 61.9539 seconds
#
# Assume we have data on quantum phase of matter.
# We want to explore ideas on quantum states and tensor networks for numerical analysis.
# Can tensor networks simulate proposal for quantum algorithms?
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00335           1201                118          1319
#
# --------------------------------------------------------------------------------
#
# **Step number:** 1 out of 6.
#
# **Sub-task:** Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
#
# **Agent in charge of sub-task:** `idea_maker`
#
# **Instructions:**
#
# - Brainstorm 5 distinct research project ideas.
# - For each idea, briefly describe the concept.
# - Clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms.
#
# **Status:** in progress ⏳
#
#
# --------------------------------------------------------------------------------
#
# Calling idea_maker...
#
#             Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4o-2024-11-20 idea_maker 0.00832           1208                530          1738
# **Ideas:**
#
# - **Idea 1: Tensor Network Representations of Quantum Phase Transitions**
#    * Description: Investigate how tensor networks can be used to model and simulate quantum phase transitions, focusing on their ability to capture the entanglement structure of quantum states during these transitions.
#    * Bullet points:
#      - Use quantum phase of matter data to identify key phase transitions.
#      - Develop tensor network models (e.g., Matrix Product States or Projected Entangled Pair States) to represent quantum states near critical points.
#      - Test whether these tensor networks can simulate quantum algorithms designed to detect or classify phase transitions.
#
# - **Idea 2: Benchmarking Tensor Networks for Quantum Algorithm Simulation**
#    * Description: Evaluate the performance of tensor networks in simulating specific quantum algorithms, such as those for solving optimization problems or simulating quantum dynamics.
#    * Bullet points:
#      - Select quantum algorithms relevant to quantum phase of matter (e.g., variational quantum eigensolvers).
#      - Use tensor networks to simulate these algorithms and compare results with theoretical predictions.
#      - Analyze the scalability and accuracy of tensor networks in this context.
#
# - **Idea 3: Tensor Networks for Topological Quantum States**
#    * Description: Explore the use of tensor networks to model topological quantum states and their potential for simulating quantum algorithms that leverage topological properties.
#    * Bullet points:
#      - Focus on quantum phase data related to topological phases of matter.
#      - Construct tensor network representations of topological states (e.g., using PEPS or MERA).
#      - Investigate how these representations can simulate quantum algorithms that exploit topological invariants.
#
# - **Idea 4: Entanglement Dynamics in Quantum Algorithms via Tensor Networks**
#    * Description: Study the entanglement dynamics of quantum states during the execution of quantum algorithms, using tensor networks as a numerical tool.
#    * Bullet points:
#      - Use quantum phase data to identify states with varying entanglement properties.
#      - Simulate quantum algorithms using tensor networks and track entanglement measures (e.g., entanglement entropy).
#      - Assess how entanglement affects the performance and feasibility of these algorithms.
#
# - **Idea 5: Tensor Network-Based Quantum Error Mitigation**
#    * Description: Investigate whether tensor networks can be used to simulate and mitigate errors in quantum algorithms, particularly in systems exhibiting quantum phase transitions.
#    * Bullet points:
#      - Use quantum phase data to identify error-prone regions in quantum systems.
#      - Develop tensor network models to simulate error propagation in quantum algorithms.
#      - Propose tensor network-based strategies for error mitigation and test their effectiveness.
#
# --------------------------------------------------------------------------------
#
# Calling idea_maker_nest...
#
# **Ideas:**
#
# - **Idea 1: Tensor Network Representations of Quantum Phase Transitions**
#    * Description: Investigate how tensor networks can be used to model and simulate quantum phase transitions, focusing on their ability to capture the entanglement structure of quantum states during these transitions.
#    * Bullet points:
#      - Use quantum phase of matter data to identify key phase transitions.
#      - Develop tensor network models (e.g., Matrix Product States or Projected Entangled Pair States) to represent quantum states near critical points.
#      - Test whether these tensor networks can simulate quantum algorithms designed to detect or classify phase transitions.
#
# - **Idea 2: Benchmarking Tensor Networks for Quantum Algorithm Simulation**
#    * Description: Evaluate the performance of tensor networks in simulating specific quantum algorithms, such as those for solving optimization problems or simulating quantum dynamics.
#    * Bullet points:
#      - Select quantum algorithms relevant to quantum phase of matter (e.g., variational quantum eigensolvers).
#      - Use tensor networks to simulate these algorithms and compare results with theoretical predictions.
#      - Analyze the scalability and accuracy of tensor networks in this context.
#
# - **Idea 3: Tensor Networks for Topological Quantum States**
#    * Description: Explore the use of tensor networks to model topological quantum states and their potential for simulating quantum algorithms that leverage topological properties.
#    * Bullet points:
#      - Focus on quantum phase data related to topological phases of matter.
#      - Construct tensor network representations of topological states (e.g., using PEPS or MERA).
#      - Investigate how these representations can simulate quantum algorithms that exploit topological invariants.
#
# - **Idea 4: Entanglement Dynamics in Quantum Algorithms via Tensor Networks**
#    * Description: Study the entanglement dynamics of quantum states during the execution of quantum algorithms, using tensor networks as a numerical tool.
#    * Bullet points:
#      - Use quantum phase data to identify states with varying entanglement properties.
#      - Simulate quantum algorithms using tensor networks and track entanglement measures (e.g., entanglement entropy).
#      - Assess how entanglement affects the performance and feasibility of these algorithms.
#
# - **Idea 5: Tensor Network-Based Quantum Error Mitigation**
#    * Description: Investigate whether tensor networks can be used to simulate and mitigate errors in quantum algorithms, particularly in systems exhibiting quantum phase transitions.
#    * Bullet points:
#      - Use quantum phase data to identify error-prone regions in quantum systems.
#      - Develop tensor network models to simulate error propagation in quantum algorithms.
#      - Propose tensor network-based strategies for error mitigation and test their effectiveness.
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                         agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 idea_maker_response_formatter 0.00489            751                424          1175
#
# **Ideas**
#
# - Idea 1:
# 	* Investigate how tensor networks can be used to model and simulate quantum phase transitions, focusing on their ability to capture the entanglement structure of quantum states during these transitions.
# 		- Use quantum phase of matter data to identify key phase transitions.
# 		- Develop tensor network models (e.g., Matrix Product States or Projected Entangled Pair States) to represent quantum states near critical points.
# 		- Test whether these tensor networks can simulate quantum algorithms designed to detect or classify phase transitions.
#
# - Idea 2:
# 	* Evaluate the performance of tensor networks in simulating specific quantum algorithms, such as those for solving optimization problems or simulating quantum dynamics.
# 		- Select quantum algorithms relevant to quantum phase of matter (e.g., variational quantum eigensolvers).
# 		- Use tensor networks to simulate these algorithms and compare results with theoretical predictions.
# 		- Analyze the scalability and accuracy of tensor networks in this context.
#
# - Idea 3:
# 	* Explore the use of tensor networks to model topological quantum states and their potential for simulating quantum algorithms that leverage topological properties.
# 		- Focus on quantum phase data related to topological phases of matter.
# 		- Construct tensor network representations of topological states (e.g., using PEPS or MERA).
# 		- Investigate how these representations can simulate quantum algorithms that exploit topological invariants.
#
# - Idea 4:
# 	* Study the entanglement dynamics of quantum states during the execution of quantum algorithms, using tensor networks as a numerical tool.
# 		- Use quantum phase data to identify states with varying entanglement properties.
# 		- Simulate quantum algorithms using tensor networks and track entanglement measures (e.g., entanglement entropy).
# 		- Assess how entanglement affects the performance and feasibility of these algorithms.
#
# - Idea 5:
# 	* Investigate whether tensor networks can be used to simulate and mitigate errors in quantum algorithms, particularly in systems exhibiting quantum phase transitions.
# 		- Use quantum phase data to identify error-prone regions in quantum systems.
# 		- Develop tensor network models to simulate error propagation in quantum algorithms.
# 		- Propose tensor network-based strategies for error mitigation and test their effectiveness.
#
#
#
# --------------------------------------------------------------------------------
#
#  in groupchat.py generated_ideas:
# **Ideas**
#
# - Idea 1:
# 	* Investigate how tensor networks can be used to model and simulate quantum phase transitions, focusing on their ability to capture the entanglement structure of quantum states during these transitions.
# 		- Use quantum phase of matter data to identify key phase transitions.
# 		- Develop tensor network models (e.g., Matrix Product States or Projected Entangled Pair States) to represent quantum states near critical points.
# 		- Test whether these tensor networks can simulate quantum algorithms designed to detect or classify phase transitions.
#
# - Idea 2:
# 	* Evaluate the performance of tensor networks in simulating specific quantum algorithms, such as those for solving optimization problems or simulating quantum dynamics.
# 		- Select quantum algorithms relevant to quantum phase of matter (e.g., variational quantum eigensolvers).
# 		- Use tensor networks to simulate these algorithms and compare results with theoretical predictions.
# 		- Analyze the scalability and accuracy of tensor networks in this context.
#
# - Idea 3:
# 	* Explore the use of tensor networks to model topological quantum states and their potential for simulating quantum algorithms that leverage topological properties.
# 		- Focus on quantum phase data related to topological phases of matter.
# 		- Construct tensor network representations of topological states (e.g., using PEPS or MERA).
# 		- Investigate how these representations can simulate quantum algorithms that exploit topological invariants.
#
# - Idea 4:
# 	* Study the entanglement dynamics of quantum states during the execution of quantum algorithms, using tensor networks as a numerical tool.
# 		- Use quantum phase data to identify states with varying entanglement properties.
# 		- Simulate quantum algorithms using tensor networks and track entanglement measures (e.g., entanglement entropy).
# 		- Assess how entanglement affects the performance and feasibility of these algorithms.
#
# - Idea 5:
# 	* Investigate whether tensor networks can be used to simulate and mitigate errors in quantum algorithms, particularly in systems exhibiting quantum phase transitions.
# 		- Use quantum phase data to identify error-prone regions in quantum systems.
# 		- Develop tensor network models to simulate error propagation in quantum algorithms.
# 		- Propose tensor network-based strategies for error mitigation and test their effectiveness.
#
#
#
# Calling idea_saver...
#
#              Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 idea_saver 0.00607           1137                474          1611
#
# --------------------------------------------------------------------------------
#
# Calling idea_saver...
#
#
# Ideas saved in /home/tda/PABLO/AstroPilot/examples/project/idea_generation_output/control/ideas_20250724_160220.json
#
#
# --------------------------------------------------------------------------------
#
# **Ideas**
#
# - Idea 1:
# 	* Investigate how tensor networks can be used to model and simulate quantum phase transitions, focusing on their ability to capture the entanglement structure of quantum states during these transitions.
# 		- Use quantum phase of matter data to identify key phase transitions.
# 		- Develop tensor network models (e.g., Matrix Product States or Projected Entangled Pair States) to represent quantum states near critical points.
# 		- Test whether these tensor networks can simulate quantum algorithms designed to detect or classify phase transitions.
#
# - Idea 2:
# 	* Evaluate the performance of tensor networks in simulating specific quantum algorithms, such as those for solving optimization problems or simulating quantum dynamics.
# 		- Select quantum algorithms relevant to quantum phase of matter (e.g., variational quantum eigensolvers).
# 		- Use tensor networks to simulate these algorithms and compare results with theoretical predictions.
# 		- Analyze the scalability and accuracy of tensor networks in this context.
#
# - Idea 3:
# 	* Explore the use of tensor networks to model topological quantum states and their potential for simulating quantum algorithms that leverage topological properties.
# 		- Focus on quantum phase data related to topological phases of matter.
# 		- Construct tensor network representations of topological states (e.g., using PEPS or MERA).
# 		- Investigate how these representations can simulate quantum algorithms that exploit topological invariants.
#
# - Idea 4:
# 	* Study the entanglement dynamics of quantum states during the execution of quantum algorithms, using tensor networks as a numerical tool.
# 		- Use quantum phase data to identify states with varying entanglement properties.
# 		- Simulate quantum algorithms using tensor networks and track entanglement measures (e.g., entanglement entropy).
# 		- Assess how entanglement affects the performance and feasibility of these algorithms.
#
# - Idea 5:
# 	* Investigate whether tensor networks can be used to simulate and mitigate errors in quantum algorithms, particularly in systems exhibiting quantum phase transitions.
# 		- Use quantum phase data to identify error-prone regions in quantum systems.
# 		- Develop tensor network models to simulate error propagation in quantum algorithms.
# 		- Propose tensor network-based strategies for error mitigation and test their effectiveness.
#
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00606           2561                117          2678
#
# --------------------------------------------------------------------------------
#
# **Step number:** 1 out of 6.
#
# **Sub-task:** Generate 5 new research project ideas related to quantum phase of matter data, quantum states, and tensor networks for numerical analysis, with a focus on whether tensor networks can simulate proposals for quantum algorithms.
#
# **Agent in charge of sub-task:** `idea_maker`
#
# **Instructions:**
#
# - Brainstorm 5 distinct research project ideas.
# - For each idea, briefly describe the concept.
# - Clearly outline how each idea connects quantum phase data, quantum states, and tensor networks in the context of simulating quantum algorithms.
#
# **Status:** completed ✅
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00624           2824                 74          2898
#
# --------------------------------------------------------------------------------
#
# **Step number:** 2 out of 6.
#
# **Sub-task:** Critique the 5 research project ideas.
#
# **Agent in charge of sub-task:** `idea_hater`
#
# **Instructions:**
#
# - Analyze the strengths and weaknesses of each idea.
# - Identify specific impractical elements or gaps in each idea.
# - Explicitly recommend targeted improvements for each idea.
#
# **Status:** in progress ⏳
#
#
# --------------------------------------------------------------------------------
#
# Calling idea_hater...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 den.get_idea()
#       2 den.show_idea()
#
# File ~/PABLO/AstroPilot/denario/denario.py:147, in Denario.get_idea(self, idea_maker_model, idea_hater_model)
#     140         self.research.data_description = f.read()
#     142 idea = Idea(work_dir = self.project_dir,
#     143             idea_maker_model = idea_maker_model.name,
#     144             idea_hater_model = idea_hater_model.name,
#     145             keys=self.keys)
# --> 147 idea = idea.develop_idea(self.research.data_description)
#     148 self.research.idea = idea
#     149 # Write idea to file
#
# File ~/PABLO/AstroPilot/denario/idea.py:61, in Idea.develop_idea(self, data_description)
#      53 def develop_idea(self, data_description: str):
#      54     """
#      55     Develops an idea based on the data description.
#      56
#      57     Args:
#      58         data_description: description of the data and tools to be used.
#      59     """
# ---> 61     results = cmbagent.planning_and_control(data_description,
#      62                           n_plan_reviews = 1,
#      63                           max_plan_steps = 6,
#      64                           idea_maker_model = self.idea_maker_model,
#      65                           idea_hater_model = self.idea_hater_model,
#      66                           plan_instructions=self.planner_append_instructions,
#      67                           work_dir = self.idea_dir,
#      68                           api_keys = self.api_keys
#      69                          )
#      71     chat_history = results['chat_history']
#      73     try:
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/cmbagent/cmbagent.py:1237, in planning_and_control(task, max_rounds_planning, max_rounds_control, max_plan_steps, n_plan_reviews, plan_instructions, engineer_instructions, researcher_instructions, hardware_constraints, max_n_attempts, planner_model, plan_reviewer_model, engineer_model, researcher_model, idea_maker_model, idea_hater_model, work_dir, researcher_filename, api_keys)
#    1233 initialization_time_control = end_time - start_time
#    1236 start_time = time.time()
# -> 1237 cmbagent.solve(task,
#    1238                 max_rounds=max_rounds_control,
#    1239                 initial_agent="control",
#    1240                 shared_context = planning_output
#    1241                 )
#    1242 end_time = time.time()
#    1243 execution_time_control = end_time - start_time
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/cmbagent/cmbagent.py:578, in CMBAgent.solve(self, task, initial_agent, shared_context, mode, step, max_rounds)
#     570 # Create the pattern
#     571 agent_pattern = AutoPattern(
#     572         agents=[agent.agent for agent in self.agents],
#     573         initial_agent=self.get_agent_from_name(initial_agent),
#     574         context_variables=context_variables,
#     575         group_manager_args = {"llm_config": self.llm_config},
#     576     )
# --> 578 chat_result, context_variables, last_agent = initiate_group_chat(
#     579     pattern=agent_pattern,
#     580     messages=this_shared_context['main_task'],
#     581     # user_agent=self.get_agent_from_name("admin"),
#     582     max_rounds = max_rounds,
#     583 )
#     585 self.final_context = copy.deepcopy(context_variables)
#     587 self.last_agent = last_agent
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/group/multi_agent_chat.py:80, in initiate_group_chat(pattern, messages, max_rounds)
#      77 if last_agent is None:
#      78     raise ValueError("No agent selected to start the conversation")
# ---> 80 chat_result = last_agent.initiate_chat(
#      81     manager,
#      82     message=last_message,
#      83     clear_history=clear_history,
#      84     summary_method=pattern.summary_method,
#      85 )
#      87 cleanup_temp_user_messages(chat_result)
#      89 return chat_result, context_variables, manager.last_speaker
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:1546, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1544     else:
#    1545         msg2send = self.generate_init_message(message, **kwargs)
# -> 1546     self.send(msg2send, recipient, silent=silent)
#    1547 # print("XXXXXXXXXX==========  in conversable_agent.py chat messages: ", self.chat_messages)
#    1548 # print("XXXXXXXXXX==========  in conversable_agent.py recipient name: ", recipient.name)
#    1549 # print("XXXXXXXXXX==========  in conversable_agent.py sender name: ", _chat_info["sender"])
#    1550 summary = self._summarize_chat(
#    1551     summary_method,
#    1552     summary_args,
#    1553     recipient,
#    1554     cache=cache,
#    1555 )
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:1211, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1209 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1210 if valid:
# -> 1211     recipient.receive(message, self, request_reply, silent)
#    1212 else:
#    1213     raise ValueError(
#    1214         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1215     )
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:1326, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1324 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1325     return
# -> 1326 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1327 if reply is not None:
#    1328     self.send(reply, sender, silent=silent)
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:3182, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    3175 # Check if this function should be triggered for this sender
#    3176 if self._match_trigger(reply_func_tuple["trigger"], sender):
#    3177     # print(f"Trigger matched for {reply_func.__name__}, executing...")
#    3178
#    3179     # Execute the reply function
#    3180     # print("\n in conversable_agent.py generate_reply reply_func_tuple:")
#    3181     # print(json.dumps(reply_func_tuple, indent=4, default=str))
# -> 3182     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    3183     # print(f"s final={final}, reply={reply}")
#    3184
#    3185     # Log the execution if logging is enabled
#    3186     if logging_enabled():
#    3187         # print("Logging reply function execution")
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/groupchat.py:1488, in GroupChatManager.run_chat(self, messages, sender, config)
#    1486         print("\n in groupchat.py generate_reply....")
#    1487         print("\n\n\n-----------------------------------\n")
# -> 1488     reply = speaker.generate_reply(sender=self)
#    1489     # print("\n\n\n-----------------------------------\n")
#    1490     # print("\n in groupchat.py reply: ", reply)
#    1491     # print("\n\n\n-----------------------------------\n")
#    (...)   1494     # import json; print(json.dumps(speaker._context_variables, indent=4))
#    1495     # import sys; sys.exit()
#    1496 except KeyboardInterrupt:
#    1497     # let the admin agent speak if interrupted
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:3182, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    3175 # Check if this function should be triggered for this sender
#    3176 if self._match_trigger(reply_func_tuple["trigger"], sender):
#    3177     # print(f"Trigger matched for {reply_func.__name__}, executing...")
#    3178
#    3179     # Execute the reply function
#    3180     # print("\n in conversable_agent.py generate_reply reply_func_tuple:")
#    3181     # print(json.dumps(reply_func_tuple, indent=4, default=str))
# -> 3182     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    3183     # print(f"s final={final}, reply={reply}")
#    3184
#    3185     # Log the execution if logging is enabled
#    3186     if logging_enabled():
#    3187         # print("Logging reply function execution")
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:2226, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    2222     messages = self._oai_messages[sender]
#    2223 # cmbagent debug
#    2224 # print('in conversable_agent.py generate_oai_reply( messages: ',  self._oai_system_message + messages)
#    2225 # print('in conversable_agent.py generate_oai_reply( client_cache: ', self.client_cache)
# -> 2226 extracted_response = self._generate_oai_reply_from_client(
#    2227     client, self._oai_system_message + messages, self.client_cache)
#    2228 # print('\n\nin conversable_agent.py generate_oai_reply extracted_response: ')
#    2229 # import pprint; pprint.pprint(extracted_response)
#    2230 # import sys; sys.exit()
#    2232 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/agentchat/conversable_agent.py:2380, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    2332             response = llm_client.create(
#    2333                     context=context,
#    2334                     messages=all_messages,
#    (...)   2337                     tool_choice=tool_choice ## cmbagent added this to force tool call
#    2338                 )
#    2341 else:
#    2342     # print("dealing with non-tool calling agent in conversable_agent.py")
#    2343     # if self.name == "engineer_response_formatter":
#    (...)   2378     #         agent=self,
#    2379     #     )
# -> 2380     response = llm_client.create(
#    2381         context=context,
#    2382         messages=all_messages,
#    2383         cache=cache,
#    2384         agent=self,
#    2385     )
#    2386 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    2389 # llm_client.print_usage_summary(mode="actual")  # print actual usage summary, i.e., excluding cached usage
#    2390 # Update dictionary containing all costs
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/oai/client.py:1260, in OpenAIWrapper.create(self, **config)
#    1255     # import sys
#    1256     # sys.exit()
#    1259 request_ts = get_current_ts()
# -> 1260 response = client.create(params)
#    1261 # cmbagent debug
#    1262 if cmbagent_debug:
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/autogen/oai/anthropic.py:316, in AnthropicClient.create(self, params)
#     313 if anthropic_params["tool_choice"] is None:
#     314     del anthropic_params["tool_choice"]
# --> 316 response = self._client.messages.create(**anthropic_params)
#     318 tool_calls = []
#     319 message_text = ""
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:283, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     281             msg = f"Missing required argument: {quote(missing[0])}"
#     282     raise TypeError(msg)
# --> 283 return func(*args, **kwargs)
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:978, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     971 if model in DEPRECATED_MODELS:
#     972     warnings.warn(
#     973         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     974         DeprecationWarning,
#     975         stacklevel=3,
#     976     )
# --> 978 return self._post(
#     979     "/v1/messages",
#     980     body=maybe_transform(
#     981         {
#     982             "max_tokens": max_tokens,
#     983             "messages": messages,
#     984             "model": model,
#     985             "metadata": metadata,
#     986             "service_tier": service_tier,
#     987             "stop_sequences": stop_sequences,
#     988             "stream": stream,
#     989             "system": system,
#     990             "temperature": temperature,
#     991             "thinking": thinking,
#     992             "tool_choice": tool_choice,
#     993             "tools": tools,
#     994             "top_k": top_k,
#     995             "top_p": top_p,
#     996         },
#     997         message_create_params.MessageCreateParamsStreaming
#     998         if stream
#     999         else message_create_params.MessageCreateParamsNonStreaming,
#    1000     ),
#    1001     options=make_request_options(
#    1002         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1003     ),
#    1004     cast_to=Message,
#    1005     stream=stream or False,
#    1006     stream_cls=Stream[RawMessageStreamEvent],
#    1007 )
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)   1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/PABLO/AstroPilot/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1085, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1082             err.response.read()
#    1084         log.debug("Re-raising status error")
# -> 1085         raise self._make_status_error_from_response(err.response) from None
#    1087     break
#    1089 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}}

# %% [markdown]
# ## Get Idea - fast method
#
# Generate a research idea from that data specification, using the faster langchain backend.

# %%
den.get_idea_fast(verbose=False)
den.show_idea()
# Out:
# Maker (iteration 1)
# Hater (iteration 1)
# Maker (iteration 2)
# Hater (iteration 2)
# Maker (iteration 3)
# Hater (iteration 3)
# Maker (iteration 4)
# done 3279 1073
# Idea generated in 0 min 11 sec.
#
# Compare 1D CNN and FCNN neural net architecture for non-linear matter power spectrum emulators in LCDM.
# Input parameters include the cosmological parameters as well as the redshift at which the power spectrum is requested.
# We want to find the architecture that is both as accurate as possible and as fast as possible to compute.
#
# Constraints:
# - use classy_sz for computing P(k,z) to generate the data.
# - Cosmological parameters are omega_b, omega_cdm, H0, logA, n_s.
# - The k-range of interest is kmin = 1e-4 [1/Mpc] to kmax = 10 [1/Mpc].
# - The z-range of interest is zmin = 0 to zmax = 3.
# - P(k) at z should always be plotted/processed in log-log scale.
# - Training set should have at least 50k spectra.
# - The training/testing data should be created in a different step as training the neural nets.
# - The step to train the neural nets should only be for training. Plotting and performances should be done in another step.

# %% [markdown]
# # Set idea
#
# Alternatively, if you already have a research idea, you can set it through text or indicating a markdown input text.

# %%
den.set_idea(idea = r"""
Compare 1D CNN and FCNN neural net architecture for non-linear matter power spectrum emulators in LCDM.
Input parameters include the cosmological parameters as well as the redshift at which the power spectrum is requested.
We want to find the architecture that is both as accurate as possible and as fast as possible to compute.

Constraints:
- use classy_sz for computing P(k,z) to generate the data.
- Cosmological parameters are omega_b, omega_cdm, H0, logA, n_s. 
- The k-range of interest is kmin = 1e-4 [1/Mpc] to kmax = 10 [1/Mpc].
- The z-range of interest is zmin = 0 to zmax = 3.
- P(k) at z should always be plotted/processed in log-log scale.
- Training set should have at least 50k spectra.
- The training/testing data should be created in a different step as training the neural nets.
- The step to train the neural nets should only be for training. Plotting and performances should be done in another step.
""")
den.show_idea()
# Out:
# Compare 1D CNN and FCNN neural net architecture for non-linear matter power spectrum emulators in LCDM.
# Input parameters include the cosmological parameters as well as the redshift at which the power spectrum is requested.
# We want to find the architecture that is both as accurate as possible and as fast as possible to compute.
#
# Constraints:
# - use classy_sz for computing P(k,z) to generate the data.
# - Cosmological parameters are omega_b, omega_cdm, H0, logA, n_s.
# - The k-range of interest is kmin = 1e-4 [1/Mpc] to kmax = 10 [1/Mpc].
# - The z-range of interest is zmin = 0 to zmax = 3.
# - P(k) at z should always be plotted/processed in log-log scale.
# - Training set should have at least 50k spectra.
# - The training/testing data should be created in a different step as training the neural nets.
# - The step to train the neural nets should only be for training. Plotting and performances should be done in another step.
